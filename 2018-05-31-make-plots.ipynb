# %% [markdown]
# # Make plots

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from pylab import *

# %%
file='NATL60OSMO-CJM165_y2012m06d14-y2013m10d01.1d_SSHdegrad.nc'
fid = nc.Dataset(file)
SSH_NAT=np.array(fid.variables["degraded_sossheig"][0:31,:,:]).squeeze()  # 471 comes from 366+15*7 and tmax=475
ssh_nat=np.zeros((SSH_NAT.shape[0],SSH_NAT.shape[1]*SSH_NAT.shape[2]))
lon1d=np.array(fid.variables["nav_lon"][:,:]).squeeze()
lat1d=np.array(fid.variables["nav_lat"][:,:]).squeeze()

# %%
SSH1=np.zeros((31,SSH_NAT.shape[1],SSH_NAT.shape[2]))
for i in range(31):    
    file='testdata/ssh0'+'_'+str(i)+'.nc'   #read the new testing data from QG and repace it in ssh_new
    fids = nc.Dataset(file)
    SSH1[i,:,:]=np.array(fids.variables["SSH"][:,:]).squeeze()

# %%
SSH2=np.zeros((31,SSH_NAT.shape[1],SSH_NAT.shape[2]))
for i in range(31):    
    file='testdata/ssh2'+'_'+str(i)+'.nc'   #read the new testing data from QG and repace it in ssh_new
    fids = nc.Dataset(file)
    SSH2[i,:,:]=np.array(fids.variables["SSH"][:,:]).squeeze()

# %%
SSH4=np.zeros((31,SSH_NAT.shape[1],SSH_NAT.shape[2]))
for i in range(31):    
    file='testdata/ssh22'+'_'+str(i)+'.nc'   #read the new testing data from QG and repace it in ssh_new
    fids = nc.Dataset(file)
    SSH4[i,:,:]=np.array(fids.variables["SSH"][:,:]).squeeze()

# %%
plt.figure() 
figure,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2)
axlist=[ax1,ax2,ax3,ax4]
vmin=-0.3
vmax=0.1
#plt.subplot(221)
fig=plt.gcf()
fig.set_size_inches(10,7)
first=ax1.pcolormesh(lon1d[:,:],lat1d[:,:],SSH_NAT[6,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
ax1.set_title('Truth at 6 days');
#plt.subplot(222)
second=ax2.pcolormesh(lon1d[:,:],lat1d[:,:],SSH1[6,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
ax2.set_title('Case 1 at 6 days');
#plt.subplot(223)
third=ax3.pcolormesh(lon1d[:,:],lat1d[:,:],SSH2[6,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
ax3.set_title('Case 2 at 6 days');
#plt.subplot(224)
forth=ax4.pcolormesh(lon1d[:,:],lat1d[:,:],SSH4[6,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
ax4.set_title('Case 4 at 6 days');
figure.colorbar(first,ax=axlist)
plt.savefig('fig6.jpg')
#plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.show()

# %%
SSH4=np.zeros((31,SSH_NAT.shape[1],SSH_NAT.shape[2]))
for i in range(31):    
    file='testqg/ssh1'+'_'+str(i)+'.nc'   #read the new testing data from QG and repace it in ssh_new
    fids = nc.Dataset(file)
    SSH4[i,:,:]=np.array(fids.variables["SSH"][:,:]).squeeze()

# %%
plt.figure() 
figure,((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8))=plt.subplots(2,4)
axlist=[ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8]
vmin=-0.3
vmax=0.1
#plt.subplot(241)
fig=plt.gcf()
fig.set_size_inches(12,7)
first=ax1.pcolormesh(lon1d[:,:],lat1d[:,:],SSH_NAT[5,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
ax1.contour(lon1d[:,:],lat1d[:,:],SSH_NAT[5,:,:],1,colors='red',linewidths=1.5)
ax1.set_title('Truth at 5 days');
#plt.subplot(242)
ax2.pcolormesh(lon1d[:,:],lat1d[:,:],SSH1[5,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax2.contour(lon1d[:,:],lat1d[:,:],SSH1[5,:,:],1,colors='red',linewidths=1.5)
ax2.set_title('SW Case_1 at 5 days');
#plt.subplot(243)
ax3.pcolormesh(lon1d[:,:],lat1d[:,:],SSH2[5,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],[' ',''])
ax3.contour(lon1d[:,:],lat1d[:,:],SSH2[5,:,:],1,colors='red',linewidths=1.5)
ax3.set_title('SW Case_2 at 5 days');
#plt.subplot(244)
ax4.pcolormesh(lon1d[:,:],lat1d[:,:],SSH4[5,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ',''])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax4.contour(lon1d[:,:],lat1d[:,:],SSH4[5,:,:],1,colors='red',linewidths=1.5)
ax4.set_title('QG at 5 days');
#plt.subplot(245)
ax5.pcolormesh(lon1d[:,:],lat1d[:,:],SSH_NAT[8,:,:],vmin=vmin, vmax=vmax)
ax5.contour(lon1d[:,:],lat1d[:,:],SSH_NAT[8,:,:],1,colors='red',linewidths=1.5)
ax5.set_title('8 days');
#plt.subplot(246)
ax6.pcolormesh(lon1d[:,:],lat1d[:,:],SSH1[8,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax6.contour(lon1d[:,:],lat1d[:,:],SSH1[8,:,:],1,colors='red',linewidths=1.5)
ax6.set_title('8 days')
#plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.subplot(247)
ax7.pcolormesh(lon1d[:,:],lat1d[:,:],SSH2[8,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax7.contour(lon1d[:,:],lat1d[:,:],SSH2[8,:,:],1,colors='red',linewidths=1.5)
ax7.set_title('8 days')
#plt.subplot(248)
ax8.pcolormesh(lon1d[:,:],lat1d[:,:],SSH4[8,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
ax8.contour(lon1d[:,:],lat1d[:,:],SSH4[8,:,:],1,colors='red',linewidths=1.5)
figure.colorbar(first,ax=axlist)
ax8.set_title('8 days')
plt.savefig('fig8.jpg')
plt.show()

# %%
plt.figure() 
figure,((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8))=plt.subplots(2,4)
axlist=[ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8]
vmin=-0.3
vmax=0.1
#plt.subplot(241)
fig=plt.gcf()
fig.set_size_inches(12,7)
first=ax1.pcolormesh(lon1d[:,:],lat1d[:,:],SSH_NAT[15,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
ax1.contour(lon1d[:,:],lat1d[:,:],SSH_NAT[15,:,:],1,colors='red',linewidths=1.5)
ax1.set_title('Truth at 15 days');
#plt.subplot(242)
ax2.pcolormesh(lon1d[:,:],lat1d[:,:],SSH1[15,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax2.contour(lon1d[:,:],lat1d[:,:],SSH1[15,:,:],1,colors='red',linewidths=1.5)
ax2.set_title('SW Case_1 at 15 days');
#plt.subplot(243)
ax3.pcolormesh(lon1d[:,:],lat1d[:,:],SSH2[15,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],[' ',''])
ax3.contour(lon1d[:,:],lat1d[:,:],SSH2[15,:,:],1,colors='red',linewidths=1.5)
ax3.set_title('SW Case_2 at 15 days');
#plt.subplot(244)
ax4.pcolormesh(lon1d[:,:],lat1d[:,:],SSH4[15,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ',''])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax4.contour(lon1d[:,:],lat1d[:,:],SSH4[15,:,:],1,colors='red',linewidths=1.5)
ax4.set_title('QG at 15 days');
#plt.subplot(245)
ax5.pcolormesh(lon1d[:,:],lat1d[:,:],SSH_NAT[25,:,:],vmin=vmin, vmax=vmax)
ax5.contour(lon1d[:,:],lat1d[:,:],SSH_NAT[25,:,:],1,colors='red',linewidths=1.5)
ax5.set_title('25 days');
#plt.subplot(246)
ax6.pcolormesh(lon1d[:,:],lat1d[:,:],SSH1[25,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax6.contour(lon1d[:,:],lat1d[:,:],SSH1[25,:,:],1,colors='red',linewidths=1.5)
ax6.set_title('25 days')
#plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.subplot(247)
ax7.pcolormesh(lon1d[:,:],lat1d[:,:],SSH2[25,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
plt.yticks([45, 50, 55],[' ', ' ', ' '])
ax7.contour(lon1d[:,:],lat1d[:,:],SSH2[25,:,:],1,colors='red',linewidths=1.5)
ax7.set_title('25 days')
#plt.subplot(248)
ax8.pcolormesh(lon1d[:,:],lat1d[:,:],SSH4[25,:,:],vmin=vmin, vmax=vmax)
plt.yticks([45, 50, 55],[' ', ' ', ' '])
plt.xticks([-20.0, -17.5, -15,-12.5],['-20', '-17.5', '-15','-12.5'])
ax8.contour(lon1d[:,:],lat1d[:,:],SSH4[25,:,:],1,colors='red',linewidths=1.5)
ax8.set_title('25 days')
figure.colorbar(first,ax=axlist)
plt.savefig('fig10.jpg')
plt.show()

# %%
plt.figure() 
vmin=-0.3
vmax=0.1
for ik in range(0,31):
    plt.pcolormesh(lon1d[:,:],lat1d[:,:],SSH[ik,:,:],vmin=vmin, vmax=vmax)
    plt.colorbar(extend='both', fraction=0.042, pad=0.04)
    plt.title('SSH_qg_{t+tint} (here after 30 days)');

    plt.show()
#print numpy.min(Cf[-1,:,:]-SSH), numpy.max(SSH)

# %%
plt.figure() 
vmin=-0.3
vmax=0.1
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.pcolormesh(lon1d[:,:],lat1d[:,:],SSH[5,:,:],vmin=vmin, vmax=vmax)
plt.xticks([-20.0, -17.5, -15,-12.5],[' ', ' ', ' ',''])
contour(lon1d[:,:],lat1d[:,:],SSH[5,:,:],2,colors='black',linewidths=1.5)
plt.title('5 days');
plt.show()
